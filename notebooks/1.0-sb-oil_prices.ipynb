# %%
#%reload 2
import matplotlib.pyplot as plt
import quandl
quandl.ApiConfig.api_key = "_epxy8PNMMrBFS5JL4_B"

# %%
start_date="2014-1-1"
end_date="2017-11-26"

# %%
# Full list: https://blog.quandl.com/api-for-commodity-data
# Oil and gasoline prices are relevant for our task
for exchange in ["CHRIS/CME_RB1", "CHRIS/CME_CL1", "CHRIS/ICE_B1", "OPEC/ORB", "ODA/POILDUB_USD", "ODA/POILAPSP_USD", "ODA/POILWTI_USD", "ODA/POILBRE_USD"]:
    mydata = quandl.get(exchange, start_date=start_date, end_date=end_date)
    plt.plot(mydata)
    plt.title(exchange)
    plt.show()
