# %%
#%reload 2
import matplotlib.pyplot as plt
import quandl
import pandas as pd
import os

# %%
GAS_STATIONS_PATH = os.path.join('..', 'data', 'raw', 'input_data', 'Eingabedaten', 'Tankstellen.csv')
GAS_PRICE_PATH = os.path.join('..', 'data', 'raw', 'input_data', 'Eingabedaten', 'Benzinpreise')

# %%
start_date="2014-6-8"
end_date="2017-9-21"

# %%
gas_stations_df = pd.read_csv(GAS_STATIONS_PATH, sep=';', names=['id', 'Name', 'Company', 'Street', 'House_Number', 'Postalcode', 'City', 'Lat', 'Long'],index_col='id')
gas_stations_df
# Out:
#                                               Name  \
# id
# 1                                  star Tankstelle
# 2                                  Esso Tankstelle
# 3                                      SYLT, TRIFT
# 4                                 DEXX-Station 188
# 5                         team Tankautomat Hesbüll
# 6                                  Aral Tankstelle
# 7                      team Tankautomat Süderlügum
# 8                                ELAN Suederluegum
# 9      OIL! tank & go Automatentankstelle Ladelund
# 10                                 AVIA Tankstelle
# 11                      OIL! Tankstelle Glücksburg
# 12                                 star Tankstelle
# 13                        team Tankautomat Medelby
# 14                       OIL! Tankstelle Flensburg
# 15                       OIL! Tankstelle Flensburg
# 16                        FLENSBURG, MUERWIKER STR
# 17                                   Martin Kriese
# 18                       FLENSBURG, HARRISLEER STR
# 19                Flensburg (24944), Schottweg  96
# 20                              CLASSIC Langballig
# 21                                 Aral Tankstelle
# 22                                  WIKING FL-Nord
# 23                              Poetzsch TankTreff
# 24                         team Tankstelle Niebüll
# 25                          bft-willer Station 158
# 26                                      Tankstelle
# 27                                   ELAN NIEBUELL
# 28                                 Aral Tankstelle
# 29                                 star Tankstelle
# 30                            HANDEWITT, AN DER B.
# ...                                            ...
# 15197                              Esso Tankstelle
# 15198                             Autoservice GmbH
# 15199                              Esso Tankstelle
# 15200                     C+C Oberallgäu Blaichach
# 15201                              Aral Tankstelle
# 15202                           MOWAG / Tankpool24
# 15203                     Farchant Hauptstrasse 10
# 15204              SB Tankstelle Iller Park Rieden
# 15205                              Aral Tankstelle
# 15206                          Kaufmarkt Sonthofen
# 15207                 BayWa Tankstelle Sonthofen I
# 15208                BayWa Tankstelle Sonthofen II
# 15209                              Esso Tankstelle
# 15210              BK- Tankstelle Frank Szinek GbR
# 15211                   Sb-Tankstelle & Autowäsche
# 15212                  SONTHOFEN, OBERSTDORFER STR
# 15213                                 AVIA Station
# 15214                              Aral Tankstelle
# 15215              GARMISCH-PARTENK. - BURGSTR. 16
# 15216    Garmisch-Partenkirchen Zugspitzstrasse 42
# 15217                              Esso Tankstelle
# 15218                 GARMISCH PARTENK., HAUPTSTR.
# 15219                         KLAIS - HAUPTSTR. 18
# 15220                        Fischen Berger Weg 15
# 15221          MITTENWALD - PARTENKIRCHNER STRASSE
# 15222                   V-Markt Fischen/Langenwang
# 15223                              Esso Tankstelle
# 15224          OBERSTDORF - SONTHOFENER STRASSE 16
# 15225                    MITTENWALD, AM BRUNNSTEIN
# 15226                              Esso Tankstelle
#
#                               Company                  Street House_Number  \
# id
# 1                                STAR         Listlandstrasse           16
# 2                                ESSO                 TRIFT 2
# 3                               Shell                 TRIFT 7          NaN
# 4                                DEXX               Dorfstr.            19
# 5                          Raiffeisen          Raiffeisenstr.            1
# 6                                ARAL     Keitumer Landstraße          NaN
# 7                                team               Hauptstr.           16
# 8                                ELAN               HAUPTSTR.            4
# 9                                OIL!           Dorfstraße 24          NaN
# 10                   Freie Tankstelle              An der B 5          NaN
# 11                               OIL!   Flensburger Str. 15 B          NaN
# 12                               STAR            Fördestrasse           80
# 13                               team               Hauptstr.           36
# 14                               OIL!      Apenrader Str. 109          NaN
# 15                               OIL!          Osterallee 207          NaN
# 16                              Shell      MUERWIKER STR. 120          NaN
# 17                              SHELL                Kielseng            1
# 18                              Shell      HARRISLEER STR. 98          NaN
# 19                               team              Schottweg            96
# 20                            CLASSIC                Poststr.            5
# 21                               ARAL              Nordstraße           20
# 22                             WIKING             Neustadt 14          NaN
# 23                           Sonstige            Industrieweg           40
# 24                               team         Gather Landstr.        29-31
# 25                                bft        An der Nordstr.             7
# 26                             UNITOL                 Ostring           59
# 27                               ELAN    BUSCH JOHANNSEN STR.            2
# 28                               ARAL  Busch Johannsen Straße            2
# 29                               STAR             Marienallee           60
# 30                              Shell        AN DER B 199 199          NaN
# ...                               ...                     ...          ...
# 15197                            ESSO          BASLER STR. 74
# 15198                             bft           Bregenzerstr.           43
# 15199                            ESSO       MARKGRAFENSTR. 28
# 15200  C+C Oberallgäu Lang-Steudler                    Hofen            18
# 15201                            ARAL     Robert-Bosch-Straße           40
# 15202                      Tankpool24            Bahnhofstr.           110
# 15203                             OMV               Hauptstr.           10
# 15204                             NaN            Mittagstraße            3
# 15205                            ARAL             Illerstraße           12
# 15206      Freie Tankstelle Kaufmarkt   Rudolf-Diesel-Straße             1
# 15207                           BayWa        Hindelanger Str.           26
# 15208                             NaN         Eichendorffstr.        13-15
# 15209                            ESSO       GRUENTENSTR. 32 A
# 15210                             NaN            Grüntenstr.           25a
# 15211                   SB-Tankstelle          Walchenseestr.           34
# 15212                           Shell   OBERSTDORFER STR. 5 A          NaN
# 15213                            AVIA        Sonthofer Straße           31
# 15214                            ARAL             Hauptstraße           20
# 15215                            Agip                Burgstr.           16
# 15216                             OMV         Zugspitzstrasse           42
# 15217                            ESSO         ZUGSPITZSTR. 44
# 15218                           Shell            HAUPTSTR. 97          NaN
# 15219                            Agip               Hauptstr.           18
# 15220                             OMV              Berger Weg           15
# 15221                          Sunoil  Partenkirchner Strasse           17
# 15222      V-Markt Fischen/Langenwang            Bundesstraße           16
# 15223                            ESSO   SONTHOFENER STR. 20 A
# 15224                            Agip     Sonthofener Strasse           16
# 15225                           Shell         AM BRUNNSTEIN 2          NaN
# 15226                            ESSO         AM BRUNNSTEIN 2
#
#       Postalcode                    City        Lat       Long
# id
# 1          25992                    List  55.015890   8.429530
# 2          25980              WESTERLAND  54.907468   8.308741
# 3          25980                    SYLT  54.904400   8.310700
# 4          25927                Aventoft  54.901300   8.822810
# 5          25927                 Hesbüll  54.900900   8.810690
# 6          25980                Sylt-Ost  54.900402   8.339205
# 7          25923              Süderlügum  54.870800   8.906840
# 8          25923            SUEDERLUEGUM  54.869200   8.906220
# 9          25926                Ladelund  54.840400   9.027780
# 10         25923                Braderup  54.834126   8.889995
# 11         24960              Glücksburg  54.827200   9.536720
# 12         24944               Flensburg  54.816680   9.474240
# 13         24994                 Medelby  54.813000   9.172290
# 14         24939               Flensburg  54.808600   9.422040
# 15         24944               Flensburg  54.803200   9.487980
# 16         24943               Flensburg  54.803100   9.456300
# 17         24937               Flensburg  54.801380   9.441820
# 18         24939               Flensburg  54.799100   9.412270
# 19         24944               Flensburg  54.799000   9.475690
# 20         24977              Langballig  54.797600   9.635370
# 21         24943               Flensburg  54.797090   9.476214
# 22         24939               Flensburg  54.796690   9.429070
# 23         24952               Harrislee  54.794100   9.372330
# 24         25899                 Niebüll  54.791200   8.833720
# 25         24989            Streichmühle  54.783500   9.673110
# 26         25899                 Niebüll  54.781883   8.851878
# 27         25899                NIEBUELL  54.779960   8.834360
# 28         25899                 Niebüll  54.779960   8.834360
# 29         24937               Flensburg  54.778710   9.414560
# 30         24983               Handewitt  54.777900   9.325760
# ...          ...                     ...        ...        ...
# 15197      79713          BAD SAECKINGEN  47.554178   7.935905
# 15198      88131                  Lindau  47.552914   9.701535
# 15199      79639         GRENZACH-WYHLEN  47.551793   7.664013
# 15200      87544               Blaichach  47.551609  10.251100
# 15201      88131                  Lindau  47.547695   9.728079
# 15202      79618      Rheinfelden-Herten  47.546730   7.737470
# 15203      82490                Farchant  47.531280  11.112620
# 15204      87527               Sonthofen  47.524601  10.261920
# 15205      87527               Sonthofen  47.523716  10.262306
# 15206      87527               Sonthofen  47.523360  10.270100
# 15207      87527               Sonthofen  47.519566  10.272649
# 15208      87527               Sonthofen  47.519566  10.272649
# 15209      87527               SONTHOFEN  47.519035  10.281966
# 15210      87527               Sonthofen  47.518950  10.281300
# 15211      82494                    Krün  47.508600  11.279400
# 15212      87527               Sonthofen  47.508100  10.275900
# 15213      87541           Bad Hindelang  47.504010  10.359387
# 15214      82467    Garmisch-Partenkirch  47.500454  11.101443
# 15215      82467       Garmisch-Partenk.  47.498931  11.087982
# 15216      82467  Garmisch-Partenkirchen  47.490580  11.076740
# 15217      82467  GARMISCH-PARTENKIRCHEN  47.490556  11.075959
# 15218      82467  GARMISCH PARTENKIRCHEN  47.490183  11.113132
# 15219      82493                   Klais  47.484642  11.237125
# 15220      87538                 Fischen  47.461820  10.267960
# 15221      82481              Mittenwald  47.444924  11.263304
# 15222      87538      Fischen/Langenwang  47.432429  10.269833
# 15223      87561              OBERSTDORF  47.415369  10.275212
# 15224      87561              Oberstdorf  47.412920  10.275360
# 15225      82481              MITTENWALD  47.399570  11.266046
# 15226      82481              MITTENWALD  47.399458  11.265886
#
# [15226 rows x 8 columns]

# %%
gas_stations_df = pd.read_csv(GAS_STATIONS_PATH, sep=';', names=['id', 'Name', 'Company', 'Street', 'House_Number', 'Postalcode', 'City', 'Lat', 'Long'],index_col='id')
gas_stations_df.loc[gas_stations_df["Company"] == 'ARAL'].sample(n=4)
# Out:
#                  Name Company               Street House_Number Postalcode  \
# id
# 6249  Aral Tankstelle    ARAL          Gartenallee            2       4827
# 1270  Aral Tankstelle    ARAL        Bahnhofstraße           62      26954
# 734   Aral Tankstelle    ARAL  Theisbrügger Straße            1      21706
# 8964  Aral Tankstelle    ARAL      Sebastianstraße          158      53474
#
#                       City        Lat       Long
# id
# 6249               Machern  51.359900  12.616976
# 1270             Nordenham  53.486813   8.475246
# 734            Drochtersen  53.715350   9.372777
# 8964  Bad Neuenahr-Ahrweil  50.545525   7.112139
